# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the dataset

# %%
life_data = pd.read_csv('C:\\Users\\DIKSHA\\Downloads\\Life Expectancy Data.csv', sep = ',')
life_data = life_data.drop('Year', axis = 1)

# %% [markdown]
# # First five rows of the dataset

# %%
life_data.head()
# Out:
#        Country      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0  Afghanistan  Developing              65.0            263.0             62
# 1  Afghanistan  Developing              59.9            271.0             64
# 2  Afghanistan  Developing              59.9            268.0             66
# 3  Afghanistan  Developing              59.5            272.0             69
# 4  Afghanistan  Developing              59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 0     0.01               71.279624         65.0      1154   19.1  ...    6.0
# 1     0.01               73.523582         62.0       492   18.6  ...   58.0
# 2     0.01               73.219243         64.0       430   18.1  ...   62.0
# 3     0.01               78.184215         67.0      2787   17.6  ...   67.0
# 4     0.01                7.097109         68.0      3013   17.2  ...   68.0
#
# ...

# %%
status = pd.get_dummies(life_data.Status)
life_data = pd.concat([life_data, status], axis = 1)
life_data = life_data.drop(['Status'], axis=1)
life_data.rename(columns = {'Deloping' : '0', 'Developed' : 1})
# Out:
#           Country  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0     Afghanistan              65.0            263.0             62     0.01
# 1     Afghanistan              59.9            271.0             64     0.01
# 2     Afghanistan              59.9            268.0             66     0.01
# 3     Afghanistan              59.5            272.0             69     0.01
# 4     Afghanistan              59.2            275.0             71     0.01
# ...           ...               ...              ...            ...      ...
# 2933     Zimbabwe              44.3            723.0             27     4.36
# 2934     Zimbabwe              44.5            715.0             26     4.06
# 2935     Zimbabwe              44.8             73.0             25     4.43
# 2936     Zimbabwe              45.3            686.0             25     1.72
# 2937     Zimbabwe              46.0            665.0             24     1.68
#
# ...

# %%
life_data = life_data.groupby('Country').mean()
life_data.head()
# Out:
#                      Life expectancy   Adult Mortality  infant deaths  \
# Country
# Afghanistan                  58.19375         269.0625        78.2500
# Albania                      75.15625          45.0625         0.6875
# Algeria                      73.61875         108.1875        20.3125
# Angola                       49.01875         328.5625        83.7500
# Antigua and Barbuda          75.05625         127.5000         0.0000
#
#                       Alcohol  percentage expenditure  Hepatitis B   Measles   \
# Country
# Afghanistan          0.014375               34.960110    64.562500  2362.2500
# Albania              4.848750              193.259091    98.000000    53.3750
# Algeria              0.406667              236.185241    78.000000  1943.8750
# Angola               5.740667              102.100268    70.222222  3561.3125
# Antigua and Barbuda  7.949333             1001.585226    98.266667     0.0000
#
# ...

# %% [markdown]
# # Different categories

# %%
life_data.columns
# Out:
# Index(['Life expectancy ', 'Adult Mortality', 'infant deaths', 'Alcohol',
#        'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling',
#        'Developed', 'Developing'],
#       dtype='object')

# %% [markdown]
# # Deleting the missing observation

# %%
data = life_data.copy()  
data = data.dropna() 
data
# Out:
#              Life expectancy   Adult Mortality  infant deaths   Alcohol  \
# Country
# Afghanistan          58.19375         269.0625        78.2500  0.014375
# Albania              75.15625          45.0625         0.6875  4.848750
# Algeria              73.61875         108.1875        20.3125  0.406667
# Angola               49.01875         328.5625        83.7500  5.740667
# Argentina            75.15625         106.0000        10.1250  7.966667
# ...                       ...              ...            ...       ...
# Uruguay              76.07500         119.9375         0.5625  6.172667
# Uzbekistan           68.03125         184.8125        21.9375  1.608667
# Vanuatu              71.38750         137.8750         0.0000  0.806667
# Zambia               53.90625         354.3125        33.4375  2.239333
# Zimbabwe             50.48750         462.3750        26.5625  4.482000
#
#              percentage expenditure  Hepatitis B   Measles       BMI   \
# Country
# ...

# %%
#Or 'data.fillna(data.mean(), inplace=True)' with this make NaN values take mean Filling the missing values with their mean

# %%
life_data.fillna(data.mean(),inplace=True)
life_data
# Out:
#                                     Life expectancy   Adult Mortality  \
# Country
# Afghanistan                                 58.19375         269.0625
# Albania                                     75.15625          45.0625
# Algeria                                     73.61875         108.1875
# Angola                                      49.01875         328.5625
# Antigua and Barbuda                         75.05625         127.5000
# ...                                              ...              ...
# Venezuela (Bolivarian Republic of)          73.38750         163.0000
# Viet Nam                                    74.77500         126.5625
# Yemen                                       63.86250         211.8125
# Zambia                                      53.90625         354.3125
# Zimbabwe                                    50.48750         462.3750
#
#                                     infant deaths   Alcohol  \
# Country
# ...

# %% [markdown]
# # Analysis of the all the categories

# %%
life_data.describe()
# Out:
#        Life expectancy   Adult Mortality  infant deaths     Alcohol  \
# count        193.000000       193.000000     193.000000  193.000000
# mean          69.168703       165.288875      28.831930    4.439884
# std            8.947254        93.670657     113.136586    3.859423
# min           46.112500        18.750000       0.000000    0.010000
# 25%           62.800000        89.000000       0.000000    0.992000
# 50%           71.731250       152.062500       2.562500    3.582667
# 75%           74.843750       214.812500      20.750000    7.420000
# max           82.537500       550.062500    1366.687500   13.497333
#
#        percentage expenditure  Hepatitis B      Measles         BMI   \
# count              193.000000   193.000000    193.000000  193.000000
# mean               708.811674    78.460168   2302.060233   39.495203
# std               1449.445611    18.376527   7886.208390   17.423220
# min                  0.000000     8.000000      0.000000    5.200000
# ...

# %%
life_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 193 entries, Afghanistan to Zimbabwe
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Life expectancy                  193 non-null    float64
#  1   Adult Mortality                  193 non-null    float64
#  2   infant deaths                    193 non-null    float64
#  3   Alcohol                          193 non-null    float64
#  4   percentage expenditure           193 non-null    float64
#  5   Hepatitis B                      193 non-null    float64
#  6   Measles                          193 non-null    float64
#  7    BMI                             193 non-null    float64
#  8   under-five deaths                193 non-null    float64
#  9   Polio                            193 non-null    float64
#  10  Total expenditure                193 non-null    float64
# ...

# %% [markdown]
# # Getting the total no. of missing observations in each field

# %%
life_data.isnull().sum()
# Out:
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# Developed                          0
# Developing                         0
# dtype: int64

# %% [markdown]
# # Effect of various diseases on the lifespan

# %%
plt.scatter(life_data[' HIV/AIDS'], life_data['Life expectancy '])
plt.xlabel('HIV/AIDS')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data.GDP, life_data['Life expectancy '])
plt.xlabel('GDP')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data[' BMI '], life_data['Life expectancy '])
plt.xlabel('BMI')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.bar(life_data['under-five deaths '], life_data['Life expectancy '])
plt.xlabel('under-five deaths')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data['Alcohol'], life_data['Life expectancy '])
plt.xlabel('Alcohol')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data['Adult Mortality'], life_data['Life expectancy '])
plt.xlabel('Adult Mortality')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data['Schooling'], life_data['Life expectancy '])
plt.xlabel('Schooling')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data['percentage expenditure'], life_data['Life expectancy '])
plt.xlabel('Percentage Healhcare expenditure')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.figure(figsize = (14, 10))
sns.heatmap(life_data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # countries with highest & lowest life expectancy

# %%
# Countries with Highest Life Expectancy
country_vs_life = life_data.groupby('Country', as_index=False)['Life expectancy '].mean()
country_vs_life.sort_values(by = 'Life expectancy ', ascending=False).head(10)
# Out:
#      Life expectancy
# 84           82.53750
# 165          82.51875
# 75           82.44375
# 166          82.33125
# 60           82.21875
# 82           82.18750
# 160          82.06875
# 7            81.81250
# 125          81.79375
# 30           81.68750

# %%
country_vs_life.sort_values(by = 'Life expectancy ', ascending = True).head(10)
# Out:
#      Life expectancy
# 152          46.11250
# 31           48.51250
# 94           48.78125
# 3            49.01875
# 100          49.89375
# 32           50.38750
# 44           50.38750
# 192          50.48750
# 164          51.32500
# 123          51.35625

# %%
life_data
# Out:
#                                     Life expectancy   Adult Mortality  \
# Country
# Afghanistan                                 58.19375         269.0625
# Albania                                     75.15625          45.0625
# Algeria                                     73.61875         108.1875
# Angola                                      49.01875         328.5625
# Antigua and Barbuda                         75.05625         127.5000
# ...                                              ...              ...
# Venezuela (Bolivarian Republic of)          73.38750         163.0000
# Viet Nam                                    74.77500         126.5625
# Yemen                                       63.86250         211.8125
# Zambia                                      53.90625         354.3125
# Zimbabwe                                    50.48750         462.3750
#
#                                     infant deaths   Alcohol  \
# Country
# ...

# %% [markdown]
# ### Life expectency has a dense distribution between 70 - 76 years

# %%
l= [life_data['Life expectancy '].dropna(), life_data['Income composition of resources'].dropna(), life_data['Schooling'].dropna()]
for i in l:
    plt.figure(figsize=(20,5))
    sns.histplot(i, kde=True, color="orange")

# %% [markdown]
# # Below plot explains following trends:
#
# Over the year, life expectancy has been increased slightly.
# Life expectancy decreases with increase in infant's death.
# Countries with high alchol consumption has high life expectancy. (I wonder how?)
# BMI and life expectancy has a linear relationship.
# Countries having chronic diseases has lower life expectancies.(Except Few)
# GDP and Life expectancy has a strong linear relationship.
# Countries with high population has slightly low life expectancy.
# As total income composition of a country increases, life expectancy also increases. (If you're rich, you're expected to live a long life)
# Last but not the least, schooling impacts the life expectancy as expected.

# %%
nr_rows = 5
nr_cols = 4

fig, axs = plt.subplots(nr_rows, nr_cols, figsize=(nr_cols*5,nr_rows*5))
numerical_feats = life_data.dtypes[life_data.dtypes != "object"].index
li_num_feats = list(numerical_feats)
li_not_plot = []
li_plot_num_feats = [c for c in list(numerical_feats) if c not in li_not_plot]
life_data.dropna(inplace = True)

for r in range(0,nr_rows):
    for c in range(0,nr_cols):  
        i = r*nr_cols+c
        if i < len(li_plot_num_feats):
            sns.regplot(x = life_data[li_plot_num_feats[i]],y = life_data["Life expectancy "] , color = 'blue', ax = axs[r][c])
            stp = stats.pearsonr(life_data[li_plot_num_feats[i]], life_data["Life expectancy "])
            str_title = "r = " + "{0:.2f}".format(stp[0]) + "      " "p = " + "{0:.2f}".format(stp[1])
            axs[r][c].set_title(str_title,fontsize=11)
            
plt.tight_layout()    
sns.set(color_codes=True)
plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-ce017b2591ec> in <module>
#      14         if i < len(li_plot_num_feats):
#      15             sns.regplot(x = life_data[li_plot_num_feats[i]],y = life_data["Life expectancy "] , color = 'blue', ax = axs[r][c])
# ---> 16             stp = stats.pearsonr(life_data[li_plot_num_feats[i]], life_data["Life expectancy "])
#      17             str_title = "r = " + "{0:.2f}".format(stp[0]) + "      " "p = " + "{0:.2f}".format(stp[1])
#      18             axs[r][c].set_title(str_title,fontsize=11)
#
# NameError: name 'stats' is not defined

# %% [markdown]
# # impact of Alcohol consumption over Life Expectancy for different continents

# %%
fig, axs = plt.subplots(2,3, figsize=(15, 6), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.5)

for conts, ax in zip(set(life_data["Continent"]), axs.flat):
    Conts = life_data[life_data['Continent'] == conts]
    sns.regplot(x = Conts['Alcohol'],y = Conts["Life expectancy "], color = 'red', ax = ax).set_title(conts)

plt.tight_layout()    
sns.set(color_codes=True)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### This shows that health standards are not the same all over the world. In the 20th century, this global inequality is reduced and similarly, life expectancy is approaching 70 to 75 years and similarly no country in the world today has a low life expectancy than countries with high life expectancy in 1800.
